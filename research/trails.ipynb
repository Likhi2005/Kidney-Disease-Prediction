# %%
import gdown

# %%
url="https://drive.google.com/file/d/1WqOq9gp-ZC2nY9QcoqTtfpCDn48Vr1o5/view?usp=sharing"

# %%
file_id=url.split('/')[-2]
file_id
# Out:
# '1WqOq9gp-ZC2nY9QcoqTtfpCDn48Vr1o5'

# %%
prefix = 'https://drive.google.com/uc?export=download&id='
gdown.download(prefix + file_id, "Chest-CT-Scan-data.zip")
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?export=download&id=1WqOq9gp-ZC2nY9QcoqTtfpCDn48Vr1o5
# From (redirected): https://drive.google.com/uc?export=download&id=1WqOq9gp-ZC2nY9QcoqTtfpCDn48Vr1o5&confirm=t&uuid=4d124a06-fb56-499d-8c8c-aefd381a76e5
# To: c:\Users\lenovo\Desktop\Kidney-Disease-Prediction\research\Chest-CT-Scan-data.zip
# 100%|██████████| 940M/940M [10:02<00:00, 1.56MB/s]
# 'Chest-CT-Scan-data.zip'
